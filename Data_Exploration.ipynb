# %%
import pandas as pd
import numpy as np
#read in the data from the csv file
df = pd.read_csv('SGJobData50000_Clean_Category.csv')   # first 50,000 rows only

# %%
#Find the Job Category with the most number of Job Postings
job_counts = (
    df.groupby("category")
      .size()
      .reset_index(name="vacancies")
      .sort_values("vacancies", ascending=False)
)

print(job_counts)
# Out:
#                              category  vacancies
# 10                        Engineering       7115
# 20             Information Technology       6969
# 1                 Admin / Secretarial       5403
# 7                    Customer Service       5258
# 36                     Sales / Retail       4856
# 27                             Others       4762
# 5           Building and Construction       4083
# 0    Accounting / Auditing / Taxation       3868
# 14                                F&B       3706
# 23           Logistics / Supply Chain       3181
# 24                      Manufacturing       2902
# 4                 Banking and Finance       2824
# 19                    Human Resources       2446
# 25       Marketing / Public Relations       2438
# 17        Healthcare / Pharmaceutical       2163
# 9              Education and Training       2083
# 6                          Consulting       1786
# 15                 General Management       1564
# 16                       General Work       1324
# 18                        Hospitality       1202
# 34             Repair and Maintenance       1142
# 30              Professional Services        973
# 2                 Advertising / Media        917
# 8                              Design        914
# 37        Sciences / Laboratory / R&D        871
# 32         Purchasing / Merchandising        840
# 13                Events / Promotions        837
# 28             Personal Care / Beauty        760
# 12               Environment / Health        684
# 3      Architecture / Interior Design        679
# 26         Medical / Therapy Services        617
# 22                              Legal        518
# 42                    Wholesale Trade        500
# 40                 Telecommunications        478
# 33  Real Estate / Property Management        472
# 35                    Risk Management        446
# 21                          Insurance        404
# 41                   Travel / Tourism        355
# 39                    Social Services        343
# 29              Precision Engineering        335
# 38         Security and Investigation        295
# 11                      Entertainment        221
# 31             Public / Civil Service        134

# %%
#To find the median salary for a particular Job Category
Category_Summary = (
    df[df["category"] == "Design"] # Edit to include requested Category
      .groupby("positionLevels")
      .agg(
          Vacancies=("average_salary", "count"),
          Median_salary=("average_salary", "median")
      )
      .reset_index()
      .sort_values("Median_salary", ascending=False)
)

print(Category_Summary)
# Out:
#       positionLevels  Vacancies  Median_salary
# 8  Senior Management         15         9000.0
# 4  Middle Management         12         6075.0
# 3            Manager         58         5750.0
# 6       Professional         75         5750.0
# 7   Senior Executive        112         5000.0
# 0          Executive        306         3500.0
# 2   Junior Executive        179         3250.0
# 5      Non-executive         70         3000.0
# 1  Fresh/entry level         87         2400.0

# %%
# median_salary = (
#     df.groupby(["category", "positionLevels"])["average_salary"]
#       .median()
#       .reset_index(name="median_salary")
# )

# print(median_salary)

summary = (
    df.groupby(["category", "positionLevels"])
      .agg(
          vacancies=("average_salary", "count"),
          median_salary=("average_salary", "median")
      )
      .reset_index()
      .sort_values("median_salary", ascending=False)
)

print(summary)
# Out:
#                         category     positionLevels  vacancies  median_salary
# 242   Medical / Therapy Services  Senior Management          8        15250.0
# 323              Risk Management  Senior Management         52        15000.0
# 44           Banking and Finance  Senior Management        168        14550.0
# 197                    Insurance  Senior Management          9        13500.0
# 368           Telecommunications  Senior Management          4        12750.0
# ..                           ...                ...        ...            ...
# 109         Environment / Health  Fresh/entry level         85         2100.0
# 100                Entertainment  Fresh/entry level         19         2100.0
# 113         Environment / Health      Non-executive        114         2075.0
# 145                 General Work  Fresh/entry level        269         1950.0
# 334  Sciences / Laboratory / R&D  Fresh/entry level        156         1950.0
#
# [387 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83668 entries, 0 to 83667
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   employmentTypes                     83668 non-null  object
#  1   metadata_expiryDate                 83668 non-null  object
#  2   metadata_isPostedOnBehalf           83668 non-null  bool
#  3   metadata_jobPostId                  83668 non-null  object
#  4   metadata_newPostingDate             83668 non-null  object
#  5   metadata_originalPostingDate        83668 non-null  object
#  6   metadata_repostCount                83668 non-null  int64
#  7   metadata_totalNumberJobApplication  83668 non-null  int64
#  8   metadata_totalNumberOfView          83668 non-null  int64
#  9   minimumYearsExperience              83668 non-null  int64
#  10  numberOfVacancies                   83668 non-null  int64
#  11  positionLevels                      83668 non-null  object
#  12  postedCompany_name                  83668 non-null  object
#  13  salary_maximum                      83668 non-null  int64
#  14  salary_minimum                      83668 non-null  int64
#  15  salary_type                         83668 non-null  object
#  16  status_id                           83668 non-null  int64
#  17  status_jobStatus                    83668 non-null  object
#  18  title                               83668 non-null  object
#  19  average_salary                      83668 non-null  float64
#  20  metadata_jobPostId_1                83668 non-null  object
#  21  category                            83668 non-null  object
#  22  category_id                         83668 non-null  int64
# dtypes: bool(1), float64(1), int64(9), object(12)
# memory usage: 14.1+ MB
